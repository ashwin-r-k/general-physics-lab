# %%
import numpy as np
import sympy as sp
from sympy.physics.hydrogen import R_nl
import seaborn as sns

# %%
# Out:
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/ashwin/anaconda3/envs/gpl/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01m
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0

# %%
R,n,l,Z,a,p,L,k=sp.symbols('R n l Z a p L k')

# %%
p=2*Z/(n*a)

# %%
L=sp.Sum( pow(-1,k+1) * pow(sp.factorial(n+l),2) *pow(p,k) /( sp.factorial(n-l-1-k)*sp.factorial(2*l+1+k)*sp.factorial(k) )  ,(k,0,n-l-1))

# %%
R = pow( (-2*Z/(n*a)) ,3/2) *pow( sp.factorial(n-l-1) / (2*n*pow(sp.factorial(n+l),3) ) ,1/2) * sp.exp( -p/2 ) *pow(p,l)*L

# %%
L
# Out:
# Sum((-1)**(k + 1)*p**k*factorial(l + n)**2/(factorial(k)*factorial(k + 2*l + 1)*factorial(-k - l + n - 1)), (k, 0, -l + n - 1))

# %%
R
# Out:
# zoo*Z*(-Z/a)**1.5*exp(-Z/a)*Sum(4*(-1)**(k + 1)*(2*Z/a)**k/(factorial(k)*factorial(-k - 1)*factorial(k + 3)), (k, 0, -1))/a

# %%
doit = True

# %%
L.subs([(n, 1), (l, 0)])
# Out:
# Sum(4*0**k*(2*Z)**k, (k, 0, 0))

# %%
L.evalf()
# Out:
# Sum((-1)**(k + 1)*p**k*factorial(l + n)**2/(factorial(k)*factorial(k + 2*l + 1)*factorial(-k - l + n - 1)), (k, 0, -l + n - 1))

# %%
sp.simplify(L.subs({n: 1, l: 0}))
# Out:
# -Sum((-1)**k*p**k*sin(pi*k)/(k*gamma(k + 2)), (k, 0, 0))/pi

# %%
sp.simplify(L)
# Out:
# -gamma(l + n + 1)**2*Sum((-1)**k*p**k/(gamma(k + 1)*gamma(-k - l + n)*gamma(k + 2*l + 2)), (k, 0, -l + n - 1))

# %%
sp.simplify(R.subs({n: 1, l: 0}))
# Out:
# nan

# %%
from sympy.physics.hydrogen import R_nl

# %%
R_nl(2,,r,Z=1)
# Out:
#   Cell In[158], line 1
#     R_nl(2,,r,Z=1)
#            ^
# SyntaxError: invalid syntax

# %%
sp.var("r")
# Out:
# r

# %%
fig = sp.plot(R_nl(3,1,r,Z=1),(r,0,20),xlabel="r/a",ylabel='Rnl')

# %%
sp.plot(sp.diff(R_nl(3,1,r,Z=1), r),(r,0,40))

# %%
sp.plot(sp.diff(R_nl(3,1,r,Z=1), r,r),(r,0,40))

# %%
sp.roots(sp.diff(R_nl(3,1,r,Z=1), r,r))
# Out:
# ---------------------------------------------------------------------------
# PolynomialError                           Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 sp.roots(sp.diff(R_nl(3,1,r,Z=1), r,r))
#
# File ~/anaconda3/envs/gpl/lib/python3.11/site-packages/sympy/polys/polyroots.py:989, in roots(f, auto, cubics, trig, quartics, quintics, multiple, filter, predicate, strict, *gens, **flags)
#     984                     return {factor_terms(k.xreplace(
#     985                         {v: k for k, v in bases})
#     986                     ): v for k, v in rv.items()}
#     988     if f.is_multivariate:
# --> 989         raise PolynomialError('multivariate polynomials are not supported')
#     991 def _update_dict(result, zeros, currentroot, k):
#     992     if currentroot == S.Zero:
#
# PolynomialError: multivariate polynomials are not supported

# %%
n=3
l=2

# %%
sp.var("r")

cond = True
maxR=0
rv=0
while cond:
    cons=0
    for i in range(6):
        if abs(R_nl(n,l,rv,Z=1)) < abs(maxR/20):
            cons=cons+1
            if cons>=4:
                cond=False
        maxR=max(maxR,abs(R_nl(n,l,rv,Z=1)))
        rv=rv+1
        
print(rv)

#sp.plot(R_nl(n,l,r,Z=1),(r,0,rv),xlabel=r'$r/a_0$', ylabel=r'$R_{nl}$',title=r"Radial wave Function of R({n},{l})",label=r"R_nl(n,l,r,Z=1)" )
# Out:
# 30

# %%
p1= sp.plot(R_nl(n,l,r,Z=1),(r,0,rv),xlabel=r'$r/a_0$', ylabel=r'$R_{nl}$',title=r"Radial wave Function of R(n={0},l={1})".format(n,l),legend=True,show=False,line_color='blue')

# %%
D=pow(r*R_nl(n,l,r,Z=1),2)

# %%
p2= sp.plot(D,(r,0,rv),xlabel=r'$r/a_0$', ylabel=r'$D_{nl}$',title=r"Probability distribution n={0},l={1}".format(n,l),legend=True,show=False,line_color='red')

# %%
plotgrid = sp.plotting.PlotGrid(1, 2, p1, p2, show=False, size=(18., 8))
plotgrid.show()

# %%
plotgrid = sp.plotting.PlotGrid(1, 2, p1, p2, show=False, size=(10., 4))
plotgrid.show()

# %%
style.use('seaborn-v0_8-poster')

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
sns.set('bmh')
sns.set_style("whitegrid", {'grid.linestyle': '--'})
sns.axes_style({'grid.linestyle': 'k-','grid.color': 'black'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[380], line 1
# ----> 1 sns.set('bmh')
#       2 sns.set_style("whitegrid", {'grid.linestyle': '--'})
#       3 sns.axes_style({'grid.linestyle': 'k-','grid.color': 'black'})
#
# File ~/anaconda3/envs/gpl/lib/python3.11/site-packages/seaborn/rcmod.py:132, in set(*args, **kwargs)
#     126 def set(*args, **kwargs):
#     127     """
#     128     Alias for :func:`set_theme`, which is the preferred interface.
#     129
#     130     This function may be removed in the future.
#     131     """
# --> 132     set_theme(*args, **kwargs)
#
# File ~/anaconda3/envs/gpl/lib/python3.11/site-packages/seaborn/rcmod.py:119, in set_theme(context, style, palette, font, font_scale, color_codes, rc)
#      82 def set_theme(context="notebook", style="darkgrid", palette="deep",
#      83               font="sans-serif", font_scale=1, color_codes=True, rc=None):
#      84     """
#      85     Set aspects of the visual theme for all matplotlib and seaborn plots.
#      86
#    (...)
#     117
#     118     """
# --> 119     set_context(context, font_scale)
#     120     set_style(style, rc={"font.family": font})
#     121     set_palette(palette, color_codes=color_codes)
#
# File ~/anaconda3/envs/gpl/lib/python3.11/site-packages/seaborn/rcmod.py:469, in set_context(context, font_scale, rc)
#     436 def set_context(context=None, font_scale=1, rc=None):
#     437     """
#     438     Set the parameters that control the scaling of plot elements.
#     439
#    (...)
#     467
#     468     """
# --> 469     context_object = plotting_context(context, font_scale, rc)
#     470     mpl.rcParams.update(context_object)
#
# File ~/anaconda3/envs/gpl/lib/python3.11/site-packages/seaborn/rcmod.py:380, in plotting_context(context, font_scale, rc)
#     378 contexts = ["paper", "notebook", "talk", "poster"]
#     379 if context not in contexts:
# --> 380     raise ValueError(f"context must be in {', '.join(contexts)}")
#     382 # Set up dictionary of default parameters
#     383 texts_base_context = {
#     384
#     385     "font.size": 12,
#    (...)
#     392
#     393 }
#
# ValueError: context must be in paper, notebook, talk, poster

# %%
plotgrid = sp.plotting.PlotGrid(1, 2, p1, p2, show=False, size=(14., 6))
plotgrid.show()
